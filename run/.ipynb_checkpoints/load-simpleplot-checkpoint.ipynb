# %%
import glob
import h5py as h5
import numpy as np
import os
import sys




from matplotlib import use
use('Agg')
from matplotlib import pyplot

# %matplotlib inline
# Out:
# /home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/ipykernel/__main__.py:11: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2827, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-38-8cd8d49e0922>", line 14, in <module>
#     get_ipython().magic(u'matplotlib inline')
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2158, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2079, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-104>", line 2, in matplotlib
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2949, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/IPython/core/pylabtools.py", line 308, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/matplotlib/__init__.py", line 1410, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/home/cs1mkg/.conda/envs/solpy/lib/python2.7/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()

# %%
files=sorted(glob.glob('output/flds.tot*'))
prtfiles=sorted(glob.glob('output/prtl.tot*'))
# go through the files
start=0
end=len(files)
interval=5
global d
d=[]

# %%
for filenum in range(start,end,interval):
    print "reading",files[filenum]
    f = h5.File(files[filenum],"r")
    f1 = h5.File(prtfiles[filenum],"r")
    dict={'bz':np.squeeze(f['bz']),'dens':np.squeeze(f['dens']),
          'pxi':np.squeeze(f1['ui']),'pyi':np.squeeze(f1['vi']),
          'pzi':np.squeeze(f1['wi']),'pxe':np.squeeze(f1['ue']),
          'pye':np.squeeze(f1['ve']),'pze':np.squeeze(f1['we']),
          'xi':np.squeeze(f1['xi']),'xe':np.squeeze(f1['xe'])}    
    d.append(dict)
# Out:
# reading output/flds.tot.001
# reading output/flds.tot.006
# reading output/flds.tot.011
# reading output/flds.tot.016
# reading output/flds.tot.021
# reading output/flds.tot.026
# reading output/flds.tot.031
# reading output/flds.tot.036
# reading output/flds.tot.041
# reading output/flds.tot.046
# reading output/flds.tot.051
# reading output/flds.tot.056
# reading output/flds.tot.061
# reading output/flds.tot.066
# reading output/flds.tot.071
# reading output/flds.tot.076
# reading output/flds.tot.081
# reading output/flds.tot.086
# reading output/flds.tot.091
# reading output/flds.tot.096
# reading output/flds.tot.101
# reading output/flds.tot.106
# reading output/flds.tot.111
# reading output/flds.tot.116
# reading output/flds.tot.121
# reading output/flds.tot.126
# reading output/flds.tot.131
# reading output/flds.tot.136
# reading output/flds.tot.141
# reading output/flds.tot.146
# reading output/flds.tot.151
# reading output/flds.tot.156
# reading output/flds.tot.161
# reading output/flds.tot.166
# reading output/flds.tot.171
# reading output/flds.tot.176
# reading output/flds.tot.181
# reading output/flds.tot.186
# reading output/flds.tot.191
# reading output/flds.tot.196

# %%
print len(dict['pxi'])
# Out:
# 5034

# %%
print len(d)
de=d[39]
rho=de['dens']
bz=de['bz']
print np.shape(rho)
# Out:
# 40
# (130, 652)

# %%
#
# Plot density field
#
fig1,ax1 = pyplot.subplots(1,2,num=1)

ax1[0].imshow(rho)
ax1[1].imshow(bz)

# %%
fig2, ax2 = pyplot.subplots()
itstep=1
it=20

cs = ax2.contourf(d[it]['bz'])
cbar = fig2.colorbar(cs)

pyplot.show()

# %%
print(files)
# Out:
# ['output/flds.tot.001', 'output/flds.tot.002', 'output/flds.tot.003', 'output/flds.tot.004', 'output/flds.tot.005', 'output/flds.tot.006', 'output/flds.tot.007', 'output/flds.tot.008', 'output/flds.tot.009', 'output/flds.tot.010', 'output/flds.tot.011', 'output/flds.tot.012', 'output/flds.tot.013', 'output/flds.tot.014', 'output/flds.tot.015', 'output/flds.tot.016', 'output/flds.tot.017', 'output/flds.tot.018', 'output/flds.tot.019', 'output/flds.tot.020', 'output/flds.tot.021', 'output/flds.tot.022', 'output/flds.tot.023', 'output/flds.tot.024', 'output/flds.tot.025', 'output/flds.tot.026', 'output/flds.tot.027', 'output/flds.tot.028', 'output/flds.tot.029', 'output/flds.tot.030', 'output/flds.tot.031', 'output/flds.tot.032', 'output/flds.tot.033', 'output/flds.tot.034', 'output/flds.tot.035', 'output/flds.tot.036', 'output/flds.tot.037', 'output/flds.tot.038', 'output/flds.tot.039', 'output/flds.tot.040', 'output/flds.tot.041', 'output/flds.tot.042', 'output/flds.tot.043', 'output/flds.tot.044', 'output/flds.tot.045', 'output/flds.tot.046', 'output/flds.tot.047', 'output/flds.tot.048', 'output/flds.tot.049', 'output/flds.tot.050', 'output/flds.tot.051', 'output/flds.tot.052', 'output/flds.tot.053', 'output/flds.tot.054', 'output/flds.tot.055', 'output/flds.tot.056', 'output/flds.tot.057', 'output/flds.tot.058', 'output/flds.tot.059', 'output/flds.tot.060', 'output/flds.tot.061', 'output/flds.tot.062', 'output/flds.tot.063', 'output/flds.tot.064', 'output/flds.tot.065', 'output/flds.tot.066', 'output/flds.tot.067', 'output/flds.tot.068', 'output/flds.tot.069', 'output/flds.tot.070', 'output/flds.tot.071', 'output/flds.tot.072', 'output/flds.tot.073', 'output/flds.tot.074', 'output/flds.tot.075', 'output/flds.tot.076', 'output/flds.tot.077', 'output/flds.tot.078', 'output/flds.tot.079', 'output/flds.tot.080', 'output/flds.tot.081', 'output/flds.tot.082', 'output/flds.tot.083', 'output/flds.tot.084', 'output/flds.tot.085', 'output/flds.tot.086', 'output/flds.tot.087', 'output/flds.tot.088', 'output/flds.tot.089', 'output/flds.tot.090', 'output/flds.tot.091', 'output/flds.tot.092', 'output/flds.tot.093', 'output/flds.tot.094', 'output/flds.tot.095', 'output/flds.tot.096', 'output/flds.tot.097', 'output/flds.tot.098', 'output/flds.tot.099', 'output/flds.tot.100', 'output/flds.tot.101', 'output/flds.tot.102', 'output/flds.tot.103', 'output/flds.tot.104', 'output/flds.tot.105', 'output/flds.tot.106', 'output/flds.tot.107', 'output/flds.tot.108', 'output/flds.tot.109', 'output/flds.tot.110', 'output/flds.tot.111', 'output/flds.tot.112', 'output/flds.tot.113', 'output/flds.tot.114', 'output/flds.tot.115', 'output/flds.tot.116', 'output/flds.tot.117', 'output/flds.tot.118', 'output/flds.tot.119', 'output/flds.tot.120', 'output/flds.tot.121', 'output/flds.tot.122', 'output/flds.tot.123', 'output/flds.tot.124', 'output/flds.tot.125', 'output/flds.tot.126', 'output/flds.tot.127', 'output/flds.tot.128', 'output/flds.tot.129', 'output/flds.tot.130', 'output/flds.tot.131', 'output/flds.tot.132', 'output/flds.tot.133', 'output/flds.tot.134', 'output/flds.tot.135', 'output/flds.tot.136', 'output/flds.tot.137', 'output/flds.tot.138', 'output/flds.tot.139', 'output/flds.tot.140', 'output/flds.tot.141', 'output/flds.tot.142', 'output/flds.tot.143', 'output/flds.tot.144', 'output/flds.tot.145', 'output/flds.tot.146', 'output/flds.tot.147', 'output/flds.tot.148', 'output/flds.tot.149', 'output/flds.tot.150', 'output/flds.tot.151', 'output/flds.tot.152', 'output/flds.tot.153', 'output/flds.tot.154', 'output/flds.tot.155', 'output/flds.tot.156', 'output/flds.tot.157', 'output/flds.tot.158', 'output/flds.tot.159', 'output/flds.tot.160', 'output/flds.tot.161', 'output/flds.tot.162', 'output/flds.tot.163', 'output/flds.tot.164', 'output/flds.tot.165', 'output/flds.tot.166', 'output/flds.tot.167', 'output/flds.tot.168', 'output/flds.tot.169', 'output/flds.tot.170', 'output/flds.tot.171', 'output/flds.tot.172', 'output/flds.tot.173', 'output/flds.tot.174 ...

# %%
itstep=1
it=20
rhot=np.zeros([40,652])
for it in range(0,39,itstep):
    dens=d[it]['dens']
    rhot[it]=dens[64][:]

# %%
print(np.shape(rhot))
# Out:
# (40, 652)

# %%
fig3, ax3 = pyplot.subplots()
itstep=1
it=20

cs = ax3.contourf(rhot)
cbar = fig3.colorbar(cs)

pyplot.show()
