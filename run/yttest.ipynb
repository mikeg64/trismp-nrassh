# %% [markdown]
# Example of generating a datset
# see https://yt-project.org/doc/examining/generic_array_data.html
#
# check also load simplplot.ipynb

# %%
import yt
import numpy as np

import os
import sys

# %%
arr = np.random.random(size=(64,64,64))

# %%
data = dict(density = (arr, "g/cm**3"))
bbox = np.array([[-1.5, 1.5], [-1.5, 1.5], [-1.5, 1.5]])
ds = yt.load_uniform_grid(data, arr.shape, length_unit="Mpc", bbox=bbox, nprocs=64)
# Out:
# yt : [INFO     ] 2019-08-13 08:51:08,958 Parameters: current_time              = 0.0
# yt : [INFO     ] 2019-08-13 08:51:08,961 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2019-08-13 08:51:08,964 Parameters: domain_left_edge          = [-1.5 -1.5 -1.5]
# yt : [INFO     ] 2019-08-13 08:51:08,967 Parameters: domain_right_edge         = [ 1.5  1.5  1.5]
# yt : [INFO     ] 2019-08-13 08:51:08,970 Parameters: cosmological_simulation   = 0.0

# %%
slc = yt.SlicePlot(ds, "z", ["density"],center=[-0.5, -0.5, -0.5])
slc.set_cmap("density", "Blues")
slc.annotate_grids(cmap=None)
slc.show()
# Out:
# yt : [INFO     ] 2019-08-13 08:51:37,852 xlim = -2.000000 1.000000
# yt : [INFO     ] 2019-08-13 08:51:37,855 ylim = -2.000000 1.000000
# yt : [INFO     ] 2019-08-13 08:51:37,859 xlim = -2.000000 1.000000
# yt : [INFO     ] 2019-08-13 08:51:37,863 ylim = -2.000000 1.000000
# yt : [INFO     ] 2019-08-13 08:51:37,866 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
posx_arr = np.random.uniform(low=-1.5, high=1.5, size=10000)
posy_arr = np.random.uniform(low=-1.5, high=1.5, size=10000)
posz_arr = np.random.uniform(low=-1.5, high=1.5, size=10000)
data = dict(density = (np.random.random(size=(64,64,64)), "Msun/kpc**3"), 
            particle_position_x = (posx_arr, 'code_length'), 
            particle_position_y = (posy_arr, 'code_length'),
            particle_position_z = (posz_arr, 'code_length'))
bbox = np.array([[-1.5, 1.5], [-1.5, 1.5], [-1.5, 1.5]])
ds = yt.load_uniform_grid(data, data["density"][0].shape, length_unit=(1.0, "Mpc"), mass_unit=(1.0,"Msun"), 
                          bbox=bbox, nprocs=4)
# Out:
# yt : [INFO     ] 2019-08-09 22:21:26,720 Parameters: current_time              = 0.0
# yt : [INFO     ] 2019-08-09 22:21:26,722 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2019-08-09 22:21:26,725 Parameters: domain_left_edge          = [-1.5 -1.5 -1.5]
# yt : [INFO     ] 2019-08-09 22:21:26,727 Parameters: domain_right_edge         = [ 1.5  1.5  1.5]
# yt : [INFO     ] 2019-08-09 22:21:26,729 Parameters: cosmological_simulation   = 0.0

# %%
slc = yt.SlicePlot(ds, "z", ["density"])
slc.set_cmap("density", "Blues")
slc.annotate_particles(0.25, p_size=12.0, col="Red")
slc.show()
# Out:
# yt : [INFO     ] 2019-08-09 09:50:13,858 xlim = -1.500000 1.500000
# yt : [INFO     ] 2019-08-09 09:50:13,861 ylim = -1.500000 1.500000
# yt : [INFO     ] 2019-08-09 09:50:13,865 xlim = -1.500000 1.500000
# yt : [INFO     ] 2019-08-09 09:50:13,867 ylim = -1.500000 1.500000
# yt : [INFO     ] 2019-08-09 09:50:13,871 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
import glob
import h5py as h5

# %%
#basedir='/mnt/xdrive/Users/cs1mkg/temp/' #For linux desktop remote mount to research data store
basedir='/shared/sp2rc2/Users/cs1mkg/temp/weibell/' #For automounted research data storage from ShARC
output='output-th0ph90sig0p1'
files=sorted(glob.glob(basedir+output+'/flds.tot*'))
prtfiles=sorted(glob.glob(basedir+output+'/prtl.tot*'))
# go through the files
start=199
end=len(files)
interval=1
global d
d=[]
end=200
interval=1

print(files)
# Out:
# ['/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.001', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.002', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.003', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.004', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.005', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.006', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.007', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.008', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.009', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.010', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.011', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.012', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.013', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.014', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.015', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.016', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.017', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.018', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.019', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.020', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.021', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.022', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.023', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.024', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.025', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.026', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.027', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.028', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.029', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.030', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.031', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.032', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.033', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.034', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.035', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.036', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.037', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.038', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.039', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.040', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.041', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.042', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.043', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.044', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.045', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.046', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.047', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.048', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.049', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.050', '/shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.051', '/shared/sp2rc2/Users ...

# %%
for filenum in range(start,end,interval):
    print "reading",files[filenum]
    f = h5.File(files[filenum],"r")
    f1 = h5.File(prtfiles[filenum],"r")
    dict={'bz':np.squeeze(f['bz']),'dens':np.squeeze(f['dens']),
          'v3x':np.squeeze(f['v3x']),'v3xi':np.squeeze(f['v3xi']),
          'pxi':np.squeeze(f1['ui']),'pyi':np.squeeze(f1['vi']),
          'pzi':np.squeeze(f1['wi']),'pxe':np.squeeze(f1['ue']),
          'pye':np.squeeze(f1['ve']),'pze':np.squeeze(f1['we']),
          'xi':np.squeeze(f1['xi']),'xe':np.squeeze(f1['xe'])}    
    d.append(dict)
# Out:
# reading /shared/sp2rc2/Users/cs1mkg/temp/weibell/output-th0ph90sig0p1/flds.tot.200

# %%
print (f.keys())
print (f1.keys())
# Out:
# [u'bx', u'by', u'bz', u'dens', u'densi', u'ex', u'ey', u'ez', u'jx', u'jy', u'jz', u'v3x', u'v3xi', u'v3y', u'v3yi', u'v3z', u'v3zi']
# [u'che', u'chi', u'gammae', u'gammai', u'inde', u'indi', u'proce', u'proci', u'time', u'ue', u'ui', u've', u'vi', u'we', u'wi', u'xe', u'xi', u'ye', u'yi', u'ze', u'zi']

# %%
units = ["gauss","gauss","gauss", "g/cm**3", "erg/cm**3", "erg/cm**3", "erg/cm**3", "K", 
         "cm/s", "cm/s", "cm/s", "cm/s", "cm/s", "cm/s"]

# %%
data1 = {k:(v.value,u) for (k,v), u in zip(f.items(),units)}
bbox1 = np.array([[-0.5, 0.5], [-0.5, 0.5], [0, 10]])

sselect="bz"

# %%
ds = yt.load_uniform_grid(data1, data1[sselect][0].shape, length_unit=1.0, bbox=bbox1, nprocs=8, 
                       periodicity=(False,False,False))
# Out:
# yt : [INFO     ] 2019-08-13 12:26:00,696 Parameters: current_time              = 0.0
# yt : [INFO     ] 2019-08-13 12:26:00,699 Parameters: domain_dimensions         = [ 69  69 325]
# yt : [INFO     ] 2019-08-13 12:26:00,702 Parameters: domain_left_edge          = [-0.5 -0.5  0. ]
# yt : [INFO     ] 2019-08-13 12:26:00,705 Parameters: domain_right_edge         = [  0.5   0.5  10. ]
# yt : [INFO     ] 2019-08-13 12:26:00,708 Parameters: cosmological_simulation   = 0.0

# %%
slc = yt.SlicePlot(ds, "x", [sselect])
slc.set_cmap(sselect, "Blues")
#slc.annotate_particles(0.25, p_size=12.0, col="Red")
slc.show()
# Out:
# yt : [INFO     ] 2019-08-13 12:26:04,579 xlim = -0.500000 0.500000
# yt : [INFO     ] 2019-08-13 12:26:04,582 ylim = 0.000000 10.000000
# yt : [INFO     ] 2019-08-13 12:26:04,585 xlim = -0.500000 0.500000
# yt : [INFO     ] 2019-08-13 12:26:04,588 ylim = 0.000000 10.000000
# yt : [INFO     ] 2019-08-13 12:26:04,592 Making a fixed resolution buffer of (('stream', 'bz')) 800 by 800
# yt : [WARNING  ] 2019-08-13 12:26:04,644 Plot image for field ('stream', 'bz') has both positive and negative values. Min = -0.000348, Max = 0.000291.
# yt : [WARNING  ] 2019-08-13 12:26:04,647 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
#Find the min and max of the field
mi, ma = ds.all_data().quantities.extrema(sselect)
#Reduce the dynamic range
mi = mi.value
ma = ma.value

# %%
# Choose a vector representing the viewing direction.
L = [0, 0, 1]
# Define the center of the camera to be the domain center
c = ds.domain_center[0]
# Define the width of the image
W = 15.0*ds.domain_width[0]
# Define the number of pixels to render
Npixels = 512

# %%
sc1 = yt.create_scene(ds, sselect)
dd1 = ds.all_data()

source = sc1[0]

source.log_field = False

tf = yt.ColorTransferFunction((mi, ma), grey_opacity=False)
tf.map_to_colormap(mi, ma, scale=15.0, colormap='hsv')

#colormaps at
#https://yt-project.org/doc/visualizing/colormaps/index.html

source.set_transfer_function(tf)

sc1.add_source(source)

cam = sc1.add_camera()
cam.width = W
cam.center = c
cam.normal_vector = L
cam.north_vector = [0, 0, 1]

# %%
sc1.show(sigma_clip=4)
# Out:
# yt : [INFO     ] 2019-08-13 12:26:29,335 Rendering scene (Can take a while).
# yt : [INFO     ] 2019-08-13 12:26:29,342 Creating volume
# <Scene Object>:
# Sources:
#     source_00: <Volume Source>:YTRegion (UniformGridData): , center=[ 0.  0.  5.] cm, left_edge=[-0.5 -0.5  0. ] cm, right_edge=[  0.5   0.5  10. ] cm transfer_function:<Color Transfer Function Object>:
# x_bounds:[-0.00035, 0.00031] nbins:256 features:
# 	('map_to_colormap', 'start(x):-0.00035', 'stop(x):0.00031', 'value(y): 15')
#
#     source_01: <Volume Source>:YTRegion (UniformGridData): , center=[ 0.  0.  5.] cm, left_edge=[-0.5 -0.5  0. ] cm, right_edge=[  0.5   0.5  10. ] cm transfer_function:<Color Transfer Function Object>:
# x_bounds:[-0.00035, 0.00031] nbins:256 features:
# 	('map_to_colormap', 'start(x):-0.00035', 'stop(x):0.00031', 'value(y): 15')
#
# Camera:
#     <Camera Object>:
# 	position:[ 1.  1.  1.] unitary
# 	focus:[ 0.  0.  0.] unitary
# 	north_vector:[0, 0, 1]
# 	width:[ 1.5  1.5  1.5] unitary
# 	light:None
# 	resolution:(512, 512)
# Lens: <Lens Object>:
# 	lens_type:plane-parallel
# 	viewpoint:[-866025.83679714 -866025.83679714 -866025.83679714] unitary

# %%
import h5py
from yt.config import ytcfg
#data_dir = ytcfg.get('yt','test_data_dir')
data_dir='/data/cs1mkg/temp'
#data_dir = ytcfg.get('yt','test_data_dir')
from yt.utilities.physical_ratios import cm_per_kpc
f = h5py.File(data_dir+"/UnigridData/turb_vels.h5", "r") # Read-only access to the file

# %%
print (f.keys())
# Out:
# [u'Bx', u'By', u'Bz', u'Density', u'MagneticEnergy', u'Temperature', u'turb_x-velocity', u'turb_y-velocity', u'turb_z-velocity', u'x-velocity', u'y-velocity', u'z-velocity']

# %%
units = ["gauss","gauss","gauss", "g/cm**3", "erg/cm**3", "K", 
         "cm/s", "cm/s", "cm/s", "cm/s", "cm/s", "cm/s"]

# %%
data = {k:(v.value,u) for (k,v), u in zip(f.items(),units)}
bbox = np.array([[-0.5, 0.5], [-0.5, 0.5], [-0.5, 0.5]])

# %%
ds = yt.load_uniform_grid(data, data["Density"][0].shape, length_unit=250.*cm_per_kpc, bbox=bbox, nprocs=8, 
                       periodicity=(False,False,False))

# %%
prj = yt.ProjectionPlot(ds, "z", ["z-velocity","Temperature","Bx"], weight_field="Density")
prj.set_log("z-velocity", False)
prj.set_log("Bx", False)
prj.show()

# %%
#Find the min and max of the field
mi, ma = ds.all_data().quantities.extrema('Temperature')
#Reduce the dynamic range
mi = mi.value + 1.5e7
ma = ma.value - 0.81e7

# %%
# Choose a vector representing the viewing direction.
L = [0.5, 0.5, 0.5]
# Define the center of the camera to be the domain center
c = ds.domain_center[0]
# Define the width of the image
W = 1.5*ds.domain_width[0]
# Define the number of pixels to render
Npixels = 512

# %%
sc = yt.create_scene(ds, 'Temperature')
dd = ds.all_data()

source = sc[0]

source.log_field = False

tf = yt.ColorTransferFunction((mi, ma), grey_opacity=False)
tf.map_to_colormap(mi, ma, scale=15.0, colormap='algae')

source.set_transfer_function(tf)

sc.add_source(source)

cam = sc.add_camera()
cam.width = W
cam.center = c
cam.normal_vector = L
cam.north_vector = [0, 0, 1]

# %%
sc.show(sigma_clip=4)
